# %% [markdown]
# ## IMPLEMENTASI BUBBLE SORT

# %%
def bubble_sort(arr):
  n = len(arr)
  for i in range(n - 1):
    for j in range(n - i - 1):
      if arr[j] > arr[j + 1]:
        arr[j], arr[j + 1] = arr[j + 1], arr[j]
  return arr

# contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy()) # menggunakan copy agar data asli tidak berubah
print("data sebelum sorting:", data)
print("data setelah bubble sort:", sorted_data)
# Out:
# data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# data setelah bubble sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# ## IMPLEMENTASI SELECTION SORT

# %%
def selection_sort(arr):
  n = len(arr)
  for i in range(n - 1):
    min_index = 1
    for j in range(i + 1, n):
      if arr[j] < arr[min_index]:
        min_index = j
    arr[i], arr[min_index] = arr[min_index], arr[i]
  return arr

# contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("data sebelum sorting:", data)
print("data setelah selection sorting:", sorted_data)
# Out:
# data sebelum sorting: [64, 25, 12, 22, 11]
# data setelah selection sorting: [11, 22, 12, 25, 64]

# %% [markdown]
# ## IMPLEMENTASI INSERTION SORT

# %%
def insertion_sort(arr):
  n = len(arr)
  for i in range(1, n):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
      arr[j + 1] = arr[j]
      j -= 1
    arr[j + 1] = key
  return arr

# contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("data sebelum sorting:", data)
print("data setelah insertion sorting:", sorted_data)
# Out:
# data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# data setelah insertion sorting: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# ## IMPLEMENTASI MERGE SORT

# %%
def merge_sort(arr):
  if len(arr) > 1:
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    merge_sort(left_half)
    merge_sort(right_half)

    i = j = k = 0

    while i < len(left_half) and j < len(right_half):
      if left_half[i] < right_half[j]:
        arr[k] = left_half[i]
        i += 1
      else:
        arr[k] = right_half[j]
        j += 1
        k += 1

      while i < len(left_half):
        arr[k] = left_half[i]
        i += 1
        k += 1

      while j < len(right_half):
        arr[k] = right_half[i]
        j += 1
        k += 1

  return arr

# contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print("data sebelum sorting", data)
print("data setelah merge sorting", sorted_data)
# Out:
# data sebelum sorting [64, 25, 12, 22, 11]
# data setelah merge sorting [11, 25, 64, 22, 22]

# %% [markdown]
# ## IMPLEMENTASI QUICK SORT

# %%
def quick_sort(arr):
  if len(arr) <= 1:
    return arr

  pivot = arr[len(arr) // 2]
  left = [x for x in arr if x < pivot]
  middle = [x for x in arr if x == pivot]
  right = [x for x in arr if x > pivot]

  return quick_sort(left) + middle + quick_sort(right)

# contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("data sebelum sorting:", data)
print("data setelah quick sorting:", sorted_data)
# Out:
# data sebelum sorting: [64, 25, 12, 22, 11]
# data setelah quick sorting: [11, 12, 22, 25, 64]

# %% [markdown]
# ## TUGAS

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        max_index = i
        for j in range(i + 1, n):
            if arr[j]["jumlah pemutaran"] > arr[max_index]["jumlah pemutaran"]:
                max_index = j
        arr[i], arr[max_index] = arr[max_index], arr[i]
    return arr


# contoh penggunaan
daftar_film = [
    {"Judul": "Iris - The Goo Goo Dolls", "jumlah pemutaran": 5000},
    {"Judul": "Aku Milikmu - Dewa19", "jumlah pemutaran": 9500},
    {"Judul": "Tarot - Feast", "jumlah pemutaran": 25000},
    {"Judul": "Everything u are - Hindia", "jumlah pemutaran": 17500},
    {"Judul": "Multo - Cup Of Joe", "jumlah pemutaran": 10000}
]

print("--- JUMLAH PEMUTARAN TERBANYAK ---")

hasil = selection_sort(daftar_film)

for i, film in enumerate(hasil, 1):
    print(f"{i}. {film['Judul']} - Jumlah Pemutaran: {film['jumlah pemutaran']}")
# Out:
# --- JUMLAH PEMUTARAN TERBANYAK ---
# 1. Tarot - Feast - Jumlah Pemutaran: 25000
# 2. Everything u are - Hindia - Jumlah Pemutaran: 17500
# 3. Multo - Cup Of Joe - Jumlah Pemutaran: 10000
# 4. Aku Milikmu - Dewa19 - Jumlah Pemutaran: 9500
# 5. Iris - The Goo Goo Dolls - Jumlah Pemutaran: 5000
